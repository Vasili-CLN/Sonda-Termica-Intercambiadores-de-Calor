# %%
#Las Siguientes lineas no requieren de ninguna modificación, 
#son las librerias necesarias para el funcionamiento de la libreta
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
import matplotlib.colors as colors
from pylab import * 
output_notebook()
colores = list(colors._colors_full_map.values())

archivo1='../Thingsboard/unidos_2.csv'

columnas  = ['ts','A3','A4','A5','A6','T3','T4']

def importa(archivo,columnas):
    
    tmp = pd.read_csv(archivo,header=None,sep=',',names = columnas,skiprows=1)
    #tmp = pd.read_csv(archivo,header=None,sep=',',names = columnas,skiprows=200)
    tmp=tmp.set_index('ts')
    tmp=tmp.dropna()
    return tmp
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
datos=importa(archivo1,columnas)
#datos.drop(['A3','T3','A5','A6'], axis=1, inplace=True)
#datos.index=pd.to_datetime(datos.index,format='%Y-%m-%d  %H:%M:%S')
datos
# Out:
#                         A3     A4     A5     A6       T3       T4
# ts
# 2020-04-02 12:18:00  26.04  24.31  23.69  23.30  23.5000  23.5000
# 2020-04-02 12:28:00  26.29  24.41  23.76  23.35  23.5000  23.5000
# 2020-04-02 12:38:00  26.76  24.53  23.80  23.37  23.4375  23.5000
# 2020-04-02 12:48:00  26.93  24.62  23.86  23.39  23.9375  23.1250
# 2020-04-02 12:58:00  27.28  24.74  23.91  23.42  24.2500  23.2500
# ...                    ...    ...    ...    ...      ...      ...
# 2020-04-12 06:58:00  25.91  25.57  25.23  25.01  24.6250  24.5625
# 2020-04-12 07:08:00  25.85  25.58  25.23  25.00  24.5625  24.5625
# 2020-04-12 07:28:00  25.71  25.49  25.17  24.99  24.5625  24.5625
# 2020-04-12 07:38:00  25.76  25.55  25.19  25.02  24.5625  24.5625
# 2020-04-12 07:48:00  25.70  25.50  25.17  25.00  24.5625  24.5625
#
# [1233 rows x 6 columns]

# %%
print('Sensor 3 comparado con canal 3')
m,b = polyfit(datos.T3, datos.A3, 1) 

plot(datos.T3, datos.A3, 'yo', datos.T3, m*datos.T3+b, '--k') 

plt.title('Sensor 3')
plt.xlabel('arduino')
plt.ylabel('adquisidor')
show() 
print('m:',m,'b:',b)


m,b = polyfit(datos.A3, datos.T3, 1)
plot(datos.A3, datos.T3, 'yo', datos.A3, m*datos.A3+b, '--k',) 
plt.title('Sensor 3')
plt.ylabel('arduino')
plt.xlabel('adquisidor')
show() 
print('m:',m,'b:',b)

print('Sensor 3 comparado con canal 4')
m,b = polyfit(datos.T3, datos.A4, 1) 

plot(datos.T3, datos.A4, 'yo', datos.T3, m*datos.T3+b, '--k') 

plt.title('Sensor 3')
plt.xlabel('arduino')
plt.ylabel('adquisidor')
show() 
print('m:',m,'b:',b)


m,b = polyfit(datos.A4, datos.T3, 1)
plot(datos.A4, datos.T3, 'yo', datos.A4, m*datos.A4+b, '--k',) 
plt.title('Sensor 3')
plt.ylabel('arduino')
plt.xlabel('adquisidor')
show() 
print('m:',m,'b:',b)
# Out:
# Sensor 3 comparado con canal 3
# m: 1.7784242233543155 b: -17.471466258119342
# m: 0.4091154578840968 b: 13.967094467594602
# Sensor 3 comparado con canal 4
# m: 0.4145479232781861 b: 14.86664873823586
# m: 1.3115764604230449 b: -8.076842069427128

# %%
print('Sensor 4 comparado con canal 3')
m,b = polyfit(datos.T4, datos.A3, 1) 

plot(datos.T4, datos.A3, 'ro', datos.T4, m*datos.T4+b, '--k') 

plt.title('Sensor 4')
plt.xlabel('arduino')
plt.ylabel('adquisidor')
show() 
print('m:',m,'b:',b)


m,b = polyfit(datos.A3, datos.T4, 1)
plot(datos.A3, datos.T4, 'ro', datos.A3, m*datos.A3+b, '--k',) 
plt.title('Sensor 4')
plt.ylabel('arduino')
plt.xlabel('adquisidor')
show() 
print('m:',m,'b:',b)

print('Sensor 4 comparado con canal 4')
m,b = polyfit(datos.T4, datos.A4, 1) 

plot(datos.T4, datos.A4, 'ro', datos.T4, m*datos.T4+b, '--k') 

plt.title('Sensor 4')
plt.xlabel('arduino')
plt.ylabel('adquisidor')
show() 
print('m:',m,'b:',b)


m,b = polyfit(datos.A4, datos.T4, 1)
plot(datos.A4, datos.T4, 'ro', datos.A4, m*datos.A4+b, '--k',) 
plt.title('Sensor 4')
plt.ylabel('arduino')
plt.xlabel('adquisidor')
show() 
print('m:',m,'b:',b)
# Out:
# Sensor 4 comparado con canal 3
# m: 2.2040316880777953 b: -27.301074761114165
# m: 0.21843143712964463 b: 18.750421275448137
# Sensor 4 comparado con canal 4
# m: 0.7229470687346448 b: 7.417115662233908
# m: 0.985399087721141 b: -0.21690773957155302
